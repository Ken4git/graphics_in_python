# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
penguin_df = sns.load_dataset("penguins")

# %%
penguin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
ax = penguin_df.head(5)[['body_mass_g','flipper_length_mm']].plot(kind="bar");
ax.set_xlabel("penguin")
ax.set_title("Penguin body_mass and flipper_length")
ax.legend(['Body mass in g', 'Flipper length in mm']);

# %%
ax = penguin_df[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm']].plot();
ax.set_xlabel("penguin");
